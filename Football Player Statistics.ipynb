# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('players_3120.csv')

# %%
df.head()
# Out:
#                    name  Age Overall rating Potential  \
# 0  15 Ronaldinho CAM ST   34             78        78
# 1  O. Hutchinson RM CAM   19             65        81
# 2            Brahim CAM   23             82        86
# 3          K. Wätjen CM   17             62        80
# 4       A. Güler CAM RM   18             77        88
#
#                   Team & Contract      ID         Height         Weight  \
# 0          Querétaro\n2014 ~ 2016   28130   182cm / 6'0"  76kg / 168lbs
# 1       Ipswich Town\n2022 ~ 2025  260145   174cm / 5'9"  65kg / 143lbs
# 2        Real Madrid\n2019 ~ 2027  231410   170cm / 5'7"  68kg / 150lbs
# 3  Borussia Dortmund\n2024 ~ 2028   70728  178cm / 5'10"  72kg / 159lbs
# 4        Real Madrid\n2023 ~ 2029  264309   175cm / 5'9"  70kg / 154lbs
#
#     foot  Best overall Best position  Growth   Value   Wage Release clause  \
# 0  Right            77           CAM       0   €4.1M   €45K             €0
# 1   Left            67           CAM      16   €1.8M    €3K          €4.5M
# 2  Right            84           CAM       4  €43.5M  €145K         €92.4M
# 3  Right            65           CAM      18     €1M   €900          €2.3M
# 4   Left            79           CAM      11    €22M   €41K         €49.5M
#
#    Total attacking Crossing Finishing Heading accuracy Short passing Volleys  \
# 0              367       84        69               50            82      82
# 1              266       48        53               49            66      50
# 2              328       75        76               30            83      64
# 3              257       48        53               45            67      44
# 4              340       80        68               41            81      70
#
#    Total skill Dribbling Curve FK Accuracy Long passing Ball control  \
# 0          430        86    86          87           81           90
# 1          304        69    52          50           65           68
# 2          379        84    74          61           75           85
# 3          292        66    52          43           65           66
# 4          403        83    84          76           79           81
#
#    Total movement Acceleration Sprint speed Agility Reactions Balance  \
# 0             313           50           48      73        70      72
# 1             366           76           69      81        61      79
# 2             429           85           85      89        79      91
# 3             356           77           68      78        59      74
# 4             380           75           69      82        69      85
#
#    Total power Shot power Jumping Stamina Strength Long shots  \
# 0          314         74      55      41       72         72
# 1          272         62      56      63       47         44
# 2          332         73      60      68       55         76
# 3          267         48      58      63       51         47
# 4          308         72      50      70       43         73
#
#    Total mentality Aggression Interceptions Att. Position Vision Penalties  \
# 0              319         60            25            66     82        86
# 1              264         41            37            60     65        61
# 2              294         44            33            78     81        58
# 3              263         47            54            54     59        49
# 4              316         42            55            68     80        71
#
#   Composure  Total defending Defensive awareness Standing tackle  \
# 0         0               78                  25              28
# 1        63              140                  40              49
# 2        79               84                  40              23
# 3        49              161                  50              55
# 4        77              155                  52              57
#
#   Sliding tackle  Total goalkeeping GK Diving GK Handling GK Kicking  \
# 0             25                 54         7          14         13
# 1             51                 39        10           7          9
# 2             21                 51        13           9         13
# 3             56                 48         9          13          7
# 4             46                 58        13          10         11
#
#   GK Positioning GK Reflexes  Total stats  Base stats  \
# 0              6          14         1875         377
# 1              5           8         1651         351
# 2             10           6         1897         409
# 3             11           8         1644         353
# 4             14          10         1960         405
#
#    International reputation  Pace / Diving  Shooting / Handling  \
# 0                         3             49                   72
# 1                         1             72                   54
# 2                         1             85                   74
# 3                         1             72                   50
# 4                         1             72                   70
#
#    Passing / Kicking  Dribbling / Reflexes  Defending / Pace  Unnamed: 64
# 0                 83                    84                28          NaN
# 1                 61                    70                44          NaN
# 2                 78                    85                31          NaN
# 3                 59                    66                52          NaN
# 4                 80                    81                52          NaN

# %%
df.shape
# Out:
# (3120, 65)

# %%
df.describe()
# Out:
#                Age             ID  Best overall       Growth  Total attacking  \
# count  3120.000000    3120.000000   3120.000000  3120.000000      3120.000000
# mean     24.218590  236637.525321     74.368910     5.875962       291.675641
# std       4.876116   39161.333184      6.430639     5.714962        72.207131
# min      16.000000      41.000000     49.000000     0.000000        51.000000
# 25%      20.000000  224285.000000     70.000000     0.000000       267.000000
# 50%      23.000000  243017.000000     75.000000     5.000000       304.000000
# 75%      27.000000  262621.000000     79.000000    10.000000       339.000000
# max      44.000000  279922.000000     93.000000    25.000000       440.000000
#
#        Total skill  Total movement  Total power  Total mentality  \
# count  3120.000000     3120.000000  3120.000000      3120.000000
# mean    307.003846      349.397756   328.516026       293.083333
# std      75.263189       52.477820    50.544401        63.164889
# min      61.000000      133.000000   146.000000        72.000000
# 25%     280.000000      325.000000   299.000000       268.000000
# 50%     321.000000      359.000000   335.000000       303.000000
# 75%     357.000000      385.000000   366.000000       334.000000
# max     465.000000      462.000000   442.000000       417.000000
#
#        Total defending  Total goalkeeping  Total stats   Base stats  \
# count      3120.000000        3120.000000  3120.000000  3120.000000
# mean        155.752564          72.398077  1797.827244   394.946474
# std          64.891734          79.925173   258.036837    38.493322
# min          24.000000          13.000000   843.000000   253.000000
# 25%          97.000000          47.000000  1670.750000   369.000000
# 50%         174.000000          52.000000  1839.000000   398.000000
# 75%         212.000000          57.000000  1973.250000   422.000000
# max         269.000000         433.000000  2330.000000   500.000000
#
#        International reputation  Pace / Diving  Shooting / Handling  \
# count               3120.000000    3120.000000          3120.000000
# mean                   1.450962      73.015385            61.509936
# std                    0.804862      10.379235            14.111539
# min                    1.000000      29.000000            21.000000
# 25%                    1.000000      67.000000            53.000000
# 50%                    1.000000      74.000000            64.000000
# 75%                    2.000000      80.000000            72.000000
# max                    5.000000      97.000000            93.000000
#
#        Passing / Kicking  Dribbling / Reflexes  Defending / Pace  Unnamed: 64
# count        3120.000000           3120.000000       3120.000000          0.0
# mean           65.975321             71.527244         54.649359          NaN
# std             9.621618              8.620042         18.068982          NaN
# min            31.000000             34.000000         16.000000          NaN
# 25%            60.000000             66.750000         38.000000          NaN
# 50%            67.000000             72.000000         58.000000          NaN
# 75%            73.000000             77.000000         70.000000          NaN
# max            94.000000             94.000000         89.000000          NaN

# %%
# no missing values
df.isnull().sum().sum()
# Out:
# 3120

# %%
# drop empty column
df.drop(columns='Unnamed: 64', inplace=True)

# %%
# standardize column names
df.columns = df.columns.str.lower().str.replace(' / ','_').str.replace(' ','_')
df.columns
# Out:
# Index(['name', 'age', 'overall_rating', 'potential', 'team_&_contract', 'id',
#        'height', 'weight', 'foot', 'best_overall', 'best_position', 'growth',
#        'value', 'wage', 'release_clause', 'total_attacking', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'total_skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing',
#        'ball_control', 'total_movement', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'total_power', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'total_mentality',
#        'aggression', 'interceptions', 'att._position', 'vision', 'penalties',
#        'composure', 'total_defending', 'defensive_awareness',
#        'standing_tackle', 'sliding_tackle', 'total_goalkeeping', 'gk_diving',
#        'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes',
#        'total_stats', 'base_stats', 'international_reputation', 'pace_diving',
#        'shooting_handling', 'passing_kicking', 'dribbling_reflexes',
#        'defending_pace'],
#       dtype='object')

# %%
# split name column into name & position column, and remove all numbers

import re

# list of soccer positions
positions = ['GK', 'LB', 'LWB', 'RB', 'RWB', 'CB', 'CAM', 'CM', 'CDM', 'LW', 'RW' ,'LM', 'RM', 'LF', 'RF', 'CF', 'ST']

def split_name_position(row):
    row = re.sub(r'\d+', '', row) # remove all numbers
    parts = row.split() # split row into parts
    name_chunk = [part for part in parts if part not in positions] # identify names
    position_chunk = [part for part in parts if part in positions] # identify positions
    
    # stitch names and positions
    name = ' '.join(name_chunk)
    position = ', '.join(position_chunk)
    return pd.Series([name, position])

df[['player_name', 'position']] = df['name'].apply(split_name_position)
df.drop('name', axis=1, inplace=True)
# get no of playable positions for each player
df['no_of_playable_positions'] = df.position.apply(lambda x: len(x.split(','))).astype(int)
sns.histplot(df['no_of_playable_positions'])
# Out:
# <Axes: xlabel='no_of_playable_positions', ylabel='Count'>

# %%
# split team_&_contract column to team & contract['start'] & contract['end'] column
df[['team', 'contract']] = df['team_&_contract'].str.split('\n', expand=True)

# extract start and end dates
df['contract_start'] = df['contract'].str.split(' ~ ').str[0]
df['contract_end'] = df['contract'].str.split(' ~ ').str[-1]

# convert 'contract_end' to last 4 characters if they are not dates
df['contract_end'] = df['contract_end'].apply(lambda x: x if x.isdigit() else x[-4:])
df.drop(['team_&_contract', 'contract'], axis=1, inplace=True)

df.head()
# Out:
#    age overall_rating potential      id         height         weight   foot  \
# 0   34             78        78   28130   182cm / 6'0"  76kg / 168lbs  Right
# 1   19             65        81  260145   174cm / 5'9"  65kg / 143lbs   Left
# 2   23             82        86  231410   170cm / 5'7"  68kg / 150lbs  Right
# 3   17             62        80   70728  178cm / 5'10"  72kg / 159lbs  Right
# 4   18             77        88  264309   175cm / 5'9"  70kg / 154lbs   Left
#
#    best_overall best_position  growth   value   wage release_clause  \
# 0            77           CAM       0   €4.1M   €45K             €0
# 1            67           CAM      16   €1.8M    €3K          €4.5M
# 2            84           CAM       4  €43.5M  €145K         €92.4M
# 3            65           CAM      18     €1M   €900          €2.3M
# 4            79           CAM      11    €22M   €41K         €49.5M
#
#    total_attacking crossing finishing heading_accuracy short_passing volleys  \
# 0              367       84        69               50            82      82
# 1              266       48        53               49            66      50
# 2              328       75        76               30            83      64
# 3              257       48        53               45            67      44
# 4              340       80        68               41            81      70
#
#    total_skill dribbling curve fk_accuracy long_passing ball_control  \
# 0          430        86    86          87           81           90
# 1          304        69    52          50           65           68
# 2          379        84    74          61           75           85
# 3          292        66    52          43           65           66
# 4          403        83    84          76           79           81
#
#    total_movement acceleration sprint_speed agility reactions balance  \
# 0             313           50           48      73        70      72
# 1             366           76           69      81        61      79
# 2             429           85           85      89        79      91
# 3             356           77           68      78        59      74
# 4             380           75           69      82        69      85
#
#    total_power shot_power jumping stamina strength long_shots  \
# 0          314         74      55      41       72         72
# 1          272         62      56      63       47         44
# 2          332         73      60      68       55         76
# 3          267         48      58      63       51         47
# 4          308         72      50      70       43         73
#
#    total_mentality aggression interceptions att._position vision penalties  \
# 0              319         60            25            66     82        86
# 1              264         41            37            60     65        61
# 2              294         44            33            78     81        58
# 3              263         47            54            54     59        49
# 4              316         42            55            68     80        71
#
#   composure  total_defending defensive_awareness standing_tackle  \
# 0         0               78                  25              28
# 1        63              140                  40              49
# 2        79               84                  40              23
# 3        49              161                  50              55
# 4        77              155                  52              57
#
#   sliding_tackle  total_goalkeeping gk_diving gk_handling gk_kicking  \
# 0             25                 54         7          14         13
# 1             51                 39        10           7          9
# 2             21                 51        13           9         13
# 3             56                 48         9          13          7
# 4             46                 58        13          10         11
#
#   gk_positioning gk_reflexes  total_stats  base_stats  \
# 0              6          14         1875         377
# 1              5           8         1651         351
# 2             10           6         1897         409
# 3             11           8         1644         353
# 4             14          10         1960         405
#
#    international_reputation  pace_diving  shooting_handling  passing_kicking  \
# 0                         3           49                 72               83
# 1                         1           72                 54               61
# 2                         1           85                 74               78
# 3                         1           72                 50               59
# 4                         1           72                 70               80
#
#    dribbling_reflexes  defending_pace    player_name position  \
# 0                  84              28     Ronaldinho  CAM, ST
# 1                  70              44  O. Hutchinson  RM, CAM
# 2                  85              31         Brahim      CAM
# 3                  66              52      K. Wätjen       CM
# 4                  81              52       A. Güler  CAM, RM
#
#    no_of_playable_positions               team contract_start contract_end
# 0                         2          Querétaro           2014         2016
# 1                         2       Ipswich Town           2022         2025
# 2                         1        Real Madrid           2019         2027
# 3                         1  Borussia Dortmund           2024         2028
# 4                         2        Real Madrid           2023         2029

# %%
# replace errant values (e.g. 'loan') with blanks
pattern = r'^\d{4}$'

df['contract_start'] = df['contract_start'].apply(lambda x: re.match(pattern, str(x)).group() if re.match(pattern, str(x)) else '')
df['contract_end'] = df['contract_end'].apply(lambda x: re.match(pattern, str(x)).group() if re.match(pattern, str(x)) else '')

df['contract_start'] = pd.to_numeric(df['contract_start'], errors='coerce').fillna(0).astype(int)
df['contract_end'] = pd.to_numeric(df['contract_end'], errors='coerce').fillna(0).astype(int)

df.contract_start.unique(), df.contract_end.unique()
# Out:
# (array([2014, 2022, 2019, 2024, 2023, 2021, 2020, 2012,    0, 2018, 2016,
#         2015, 2017, 2010, 2011, 2013, 2008, 1993, 1998, 2009, 1999, 2007]),
#  array([2016, 2025, 2027, 2028, 2029, 2026, 2024, 2030,    0, 2031, 2032,
#         2023, 2017, 2020, 2021, 2018, 2014, 2022, 2013, 2009, 2010, 2019,
#         2015, 2012]))

# %%
df.contract_end.unique()
# Out:
# array([2016, 2025, 2027, 2028, 2029, 2026, 2024, 2030,    0, 2031, 2032,
#        2023, 2017, 2020, 2021, 2018, 2014, 2022, 2013, 2009, 2010, 2019,
#        2015, 2012])

# %%
sns.histplot(df[df['contract_end']>0]['contract_end'])
# Out:
# <Axes: xlabel='contract_end', ylabel='Count'>

# %%
# remove € from value, wage, release_clause columns

# check units
print(df.value.str[-1].unique())
print(df.wage.str[-1].unique())
print(df.release_clause.str[-1].unique())

def convert_value(value):
    if 'K' in value:
        return float(value.replace('€', '').replace('K', '')) * 1000
    elif 'M' in value:
        return float(value.replace('€', '').replace('M', '')) * 1000000
    else:
        return float(value.replace('€', ''))

# remove '€' and convert K and M in 'value', 'wage', and 'release_clause' columns
df['value'] = df['value'].apply(convert_value)
df['wage'] = df['wage'].apply(convert_value)
df['release_clause'] = df['release_clause'].apply(convert_value)

df.head()
# Out:
# ['M' '0' 'K']
# ['K' '0']
# ['0' 'M' 'K']
#    age overall_rating potential      id         height         weight   foot  \
# 0   34             78        78   28130   182cm / 6'0"  76kg / 168lbs  Right
# 1   19             65        81  260145   174cm / 5'9"  65kg / 143lbs   Left
# 2   23             82        86  231410   170cm / 5'7"  68kg / 150lbs  Right
# 3   17             62        80   70728  178cm / 5'10"  72kg / 159lbs  Right
# 4   18             77        88  264309   175cm / 5'9"  70kg / 154lbs   Left
#
#    best_overall best_position  growth       value      wage  release_clause  \
# 0            77           CAM       0   4100000.0   45000.0             0.0
# 1            67           CAM      16   1800000.0    3000.0       4500000.0
# 2            84           CAM       4  43500000.0  145000.0      92400000.0
# 3            65           CAM      18   1000000.0     900.0       2300000.0
# 4            79           CAM      11  22000000.0   41000.0      49500000.0
#
#    total_attacking crossing finishing heading_accuracy short_passing volleys  \
# 0              367       84        69               50            82      82
# 1              266       48        53               49            66      50
# 2              328       75        76               30            83      64
# 3              257       48        53               45            67      44
# 4              340       80        68               41            81      70
#
#    total_skill dribbling curve fk_accuracy long_passing ball_control  \
# 0          430        86    86          87           81           90
# 1          304        69    52          50           65           68
# 2          379        84    74          61           75           85
# 3          292        66    52          43           65           66
# 4          403        83    84          76           79           81
#
#    total_movement acceleration sprint_speed agility reactions balance  \
# 0             313           50           48      73        70      72
# 1             366           76           69      81        61      79
# 2             429           85           85      89        79      91
# 3             356           77           68      78        59      74
# 4             380           75           69      82        69      85
#
#    total_power shot_power jumping stamina strength long_shots  \
# 0          314         74      55      41       72         72
# 1          272         62      56      63       47         44
# 2          332         73      60      68       55         76
# 3          267         48      58      63       51         47
# 4          308         72      50      70       43         73
#
#    total_mentality aggression interceptions att._position vision penalties  \
# 0              319         60            25            66     82        86
# 1              264         41            37            60     65        61
# 2              294         44            33            78     81        58
# 3              263         47            54            54     59        49
# 4              316         42            55            68     80        71
#
#   composure  total_defending defensive_awareness standing_tackle  \
# 0         0               78                  25              28
# 1        63              140                  40              49
# 2        79               84                  40              23
# 3        49              161                  50              55
# 4        77              155                  52              57
#
#   sliding_tackle  total_goalkeeping gk_diving gk_handling gk_kicking  \
# 0             25                 54         7          14         13
# 1             51                 39        10           7          9
# 2             21                 51        13           9         13
# 3             56                 48         9          13          7
# 4             46                 58        13          10         11
#
#   gk_positioning gk_reflexes  total_stats  base_stats  \
# 0              6          14         1875         377
# 1              5           8         1651         351
# 2             10           6         1897         409
# 3             11           8         1644         353
# 4             14          10         1960         405
#
#    international_reputation  pace_diving  shooting_handling  passing_kicking  \
# 0                         3           49                 72               83
# 1                         1           72                 54               61
# 2                         1           85                 74               78
# 3                         1           72                 50               59
# 4                         1           72                 70               80
#
#    dribbling_reflexes  defending_pace    player_name position  \
# 0                  84              28     Ronaldinho  CAM, ST
# 1                  70              44  O. Hutchinson  RM, CAM
# 2                  85              31         Brahim      CAM
# 3                  66              52      K. Wätjen       CM
# 4                  81              52       A. Güler  CAM, RM
#
#    no_of_playable_positions               team  contract_start  contract_end
# 0                         2          Querétaro            2014          2016
# 1                         2       Ipswich Town            2022          2025
# 2                         1        Real Madrid            2019          2027
# 3                         1  Borussia Dortmund            2024          2028
# 4                         2        Real Madrid            2023          2029

# %%
plt.figure(figsize=(16,5))
sns.boxplot(x=df.value)
plt.xlabel('Player value')
# Out:
# Text(0.5, 0, 'Player value')

# %%
# clean height and weight columns
df['height'] = df['height'].str.extract(r'(\d+)')
df['weight'] = df['weight'].str.extract(r'(\d+)')

df[['height', 'weight']].head()
# Out:
#   height weight
# 0    182     76
# 1    174     65
# 2    170     68
# 3    178     72
# 4    175     70

# %%
sns.heatmap(df.select_dtypes(include='number').corr(), annot=False)
# Out:
# <Axes: >

# %%
# get top 10 correlated variables with respect to 'value' column
top_correlations = df.select_dtypes(include='number').corr().abs().sort_values(by='value', ascending=False)[1:11]
top_correlated_variables = ['value']
top_correlated_variables.extend(list(top_correlations.index))

sns.heatmap(df[top_correlated_variables].corr(), annot=True)
# Out:
# <Axes: >

# %%
# group each player's (best) position as goalkeeper, defender, midfielder, and forward
print(df.best_position.unique(), '\n')

position_mapping = {
    'GK': 'Goalkeeper',
    'CB': 'Defender',
    'LB': 'Defender',
    'RB': 'Defender',
    'RWB': 'Defender',
    'LWB': 'Defender',
    'CDM': 'Midfielder',
    'CM': 'Midfielder',
    'CAM': 'Midfielder',
    'LM': 'Midfielder',
    'RM': 'Midfielder',
    'RW': 'Forward',
    'LW': 'Forward',
    'CF': 'Forward',
    'ST': 'Forward'
}

df['core_position'] = df['best_position'].map(position_mapping)
df.core_position.value_counts()
# Out:
# ['CAM' 'ST' 'LWB' 'CB' 'CM' 'RM' 'CDM' 'LM' 'RB' 'RWB' 'LB' 'LW' 'GK' 'CF'
#  'RW']
# core_position
# Midfielder    1411
# Defender       889
# Forward        604
# Goalkeeper     216
# Name: count, dtype: int64

# %%
df.height = df.height.astype(int)
df_defenders = df.loc[df['core_position'] == 'Defender']

plt.figure(figsize=(10,6))
plt.xticks(rotation=45)

sns.scatterplot(data=df_defenders, x='height', y='value', hue='international_reputation')
# Out:
# <Axes: xlabel='height', ylabel='value'>

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=45)

sns.scatterplot(data=df, x='best_overall', y='value', hue='core_position')
# Out:
# <Axes: xlabel='best_overall', ylabel='value'>

# %%
plt.figure(figsize=(12,4))
sns.boxplot(data=df, y='core_position', x='value')
# Out:
# <Axes: xlabel='value', ylabel='core_position'>

# %%
# create age range brackets
age_bins = [10, 20, 30, 40]
age_labels = ['10-19', '20-29', '30-39']

df['age_brackets'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)
df[['age', 'age_brackets']].head()
# Out:
#    age age_brackets
# 0   34        30-39
# 1   19        10-19
# 2   23        20-29
# 3   17        10-19
# 4   18        10-19

# %%
df.potential = df.potential.str[:2].astype(int)
df.potential.unique()
# Out:
# array([78, 81, 86, 80, 88, 75, 87, 92, 82, 90, 89, 94, 85, 84, 77, 83, 91,
#        93, 73, 74, 76, 72, 79, 69, 71, 70, 64, 68, 65, 67, 66, 61, 62, 63,
#        57, 54])

# %%
df_midfielders = df.loc[df['core_position'] == 'Midfielder']

sns.scatterplot(data=df_midfielders, x='best_overall', y='value', hue='age_brackets')
plt.title('Overall stats vs value for Midfielders')
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(data=df_midfielders, x='potential', y='value', hue='age_brackets')
# Out:
# <Axes: xlabel='potential', ylabel='value'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler, RobustScaler
features = ['best_overall', 'age', 'growth', 'total_attacking', 'total_skill', 'international_reputation', 'dribbling_reflexes', 'passing_kicking']
label = 'value'
# scale features
scaler = StandardScaler()

X = df_midfielders[features]
X = scaler.fit_transform(X)
X = pd.DataFrame(X, columns=features)

y = df_midfielders[label]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=14)

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

y_pred_lr = lr_model.predict(X_test)
rmse_lr = np.sqrt(mean_squared_error(y_test, y_pred_lr))

print(f"RMSE: {rmse_lr}")
# Out:
# RMSE: 9986093.810838005

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))

print(f"RMSE: {rmse_rf}")
# Out:
# RMSE: 4126979.4480384565

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20],
}

rf_model = RandomForestRegressor(random_state=42)
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best Parameters:", best_params)
print("Best Estimator:", best_estimator)
# Out:
# Best Parameters: {'max_depth': 10, 'n_estimators': 300}
# Best Estimator: RandomForestRegressor(max_depth=10, n_estimators=300, random_state=42)

# %%
feature_importances = best_estimator.feature_importances_
feature_importance_dict = dict(zip(X_train.columns, feature_importances))

feature_importance_dict
# Out:
# {'best_overall': 0.900334008142926,
#  'age': 0.040915691109551164,
#  'growth': 0.02180049532800759,
#  'total_attacking': 0.005672896123961745,
#  'total_skill': 0.010545330516228673,
#  'international_reputation': 0.003363727903966808,
#  'dribbling_reflexes': 0.010079285817096629,
#  'passing_kicking': 0.007288565058261372}

# %%
y_pred_best = best_estimator.predict(X_test)
rmse_best = np.sqrt(mean_squared_error(y_test, y_pred_best))

print(f'RMSE of best model: {rmse_best}')
# Out:
# RMSE of best model: 4281984.398210696

# %%
y_pred_best[:10]
# Out:
# array([16467816.8885008 ,  7599268.49322926, 16955075.21591532,
#         2774906.21202866,  5227656.32643525,   850158.590418  ,
#         2621286.93445709,  1614915.18644614, 10819642.17148918,
#         1211257.46380044])

# %%
data_for_prediction = df.loc[X_test.index]
data_for_prediction.head()
# Out:
#       age overall_rating  potential      id  height weight   foot  \
# 292    22           78-1         84  248695     190     84  Right
# 568    25             77         80  243388     186     79   Left
# 428    26             81         82  227813     175     64   Left
# 1174   25             79         80  227174     185     74  Right
# 1123   21             72         82  257896     183     80  Right
#
#       best_overall best_position  growth       value      wage  \
# 292             80            CB       6  20500000.0   73000.0
# 568             78           LWB       3  13000000.0   15000.0
# 428             83            CM       1  27500000.0  105000.0
# 1174            79            RB       1  19000000.0   73000.0
# 1123            72            RB      10   5000000.0   18000.0
#
#       release_clause  total_attacking crossing finishing heading_accuracy  \
# 292       43100000.0              265     42+3     39+10               73
# 568       19200000.0              312       87        41               64
# 428       52900000.0              359       84        58               70
# 1174      37500000.0              321       77        66               49
# 1123      10500000.0              273       63        41               62
#
#      short_passing volleys  total_skill dribbling curve fk_accuracy  \
# 292             72    39-1          287        63  46+7        44+6
# 568             76      44          379        76    84          68
# 428             86      61          412        84    83          76
# 1174            74      55          340        75    70          48
# 1123            66      41          313        70    56          57
#
#      long_passing ball_control  total_movement acceleration sprint_speed  \
# 292            67           67             329           63           78
# 568            72           79             366           72           76
# 428            84           85             372           73           61
# 1174           71           76             385           78           80
# 1123           61           69             364           74           79
#
#      agility reactions balance  total_power shot_power jumping stamina  \
# 292       60        73    55-2          309       50+2      80    60-2
# 568       72        77      69          357         70      74      79
# 428       79        81      78          365         78      74      77
# 1174      78        79      70          364         77      69      86
# 1123      72        67      72          319         62      74      74
#
#      strength long_shots  total_mentality aggression interceptions  \
# 292        80       39+2              300       80-1          80-2
# 568        69         65              313         65            71
# 428        63         73              372         74            80
# 1174       68         64              341         84            76
# 1123       68         41              284         74            66
#
#      att._position vision penalties composure  total_defending  \
# 292           39-3   55+8      46-2        72              241
# 568             69     77        31        76              213
# 428             77     83        58        81              236
# 1174            71     66        44        72              237
# 1123            55     54        35        58              215
#
#      defensive_awareness standing_tackle sliding_tackle  total_goalkeeping  \
# 292                   80            81-1             80                 55
# 568                   67              71             75                 39
# 428                   77              80             79                 61
# 1174                  77              80             80                 65
# 1123                  70              73             72                 44
#
#      gk_diving gk_handling gk_kicking gk_positioning gk_reflexes  total_stats  \
# 292         14          12          9             14           6         1786
# 568         10           6          6              8           9         1979
# 428         15          11         13             11          11         2177
# 1174        15          16         13             13           8         2053
# 1123         7          13          9              7           8         1812
#
#       base_stats  international_reputation  pace_diving  shooting_handling  \
# 292          391                         1           71                 42
# 568          422                         2           74                 53
# 428          446                         2           66                 66
# 1174         442                         2           79                 66
# 1123         394                         1           77                 46
#
#       passing_kicking  dribbling_reflexes  defending_pace   player_name  \
# 292                59                  64              80     W. Fofana
# 568                78                  76              70       B. Sosa
# 428                84                  83              78  O. Zinchenko
# 1174               71                  75              75       M. Cash
# 1123               61                  69              70  N. Patterson
#
#          position  no_of_playable_positions         team  contract_start  \
# 292            CB                         1      Chelsea            2022
# 568            LB                         1         Ajax            2023
# 428            LB                         1      Arsenal            2022
# 1174  RB, RWB, RM                         3  Aston Villa            2020
# 1123      RB, RWB                         2      Everton            2022
#
#       contract_end core_position age_brackets
# 292           2029      Defender        20-29
# 568           2028      Defender        20-29
# 428           2027    Midfielder        20-29
# 1174          2027      Defender        20-29
# 1123          2027      Defender        20-29

# %%
data_for_prediction['predicted_value'] = y_pred_best.astype(int)
data_for_prediction['gap'] = data_for_prediction['predicted_value'] - data_for_prediction['value']
data_for_prediction[['player_name', 'best_overall', 'potential', 'value', 'predicted_value', 'gap']]
# Out:
#        player_name  best_overall  potential       value  predicted_value  \
# 292      W. Fofana            80         84  20500000.0         16467816
# 568        B. Sosa            78         80  13000000.0          7599268
# 428   O. Zinchenko            83         82  27500000.0         16955075
# 1174       M. Cash            79         80  19000000.0          2774906
# 1123  N. Patterson            72         82   5000000.0          5227656
# ...            ...           ...        ...         ...              ...
# 168      G. Restes            75         87  11500000.0         95224761
# 800   Pablo Maffeo            79         82  21500000.0         11816874
# 1134  Lee Han Beom            72         81   3300000.0          2936642
# 966       L. Kelly            76         77   5000000.0          1498218
# 248      L. Mercan            68         74   2000000.0         29353601
#
#              gap
# 292   -4032184.0
# 568   -5400732.0
# 428  -10544925.0
# 1174 -16225094.0
# 1123    227656.0
# ...          ...
# 168   83724761.0
# 800   -9683126.0
# 1134   -363358.0
# 966   -3501782.0
# 248   27353601.0
#
# [283 rows x 6 columns]

# %%
sns.displot(data_for_prediction.gap)

# %%
# top undervalued players to buy
under_valued_midfielders = data_for_prediction.loc[data_for_prediction['gap'] >= 1e7]
under_valued_midfielders[['player_name', 'best_overall', 'potential', 'age', 'gap']].sort_values(by='gap', ascending=False).head(30)
# Out:
#          player_name  best_overall  potential  age          gap
# 51       R. Bardghji            71         85   17  136755000.0
# 148      S. Szmodics            75         75   27   91131428.0
# 358         M. Soulé            76         86   20   87318095.0
# 168        G. Restes            75         87   18   83724761.0
# 75    W. Zaïre-Emery            82         90   17   73748333.0
# 100         Palhinha            86         85   27   69821666.0
# 201     A. Vermeeren            78         87   18   68407111.0
# 112      R. Bardghji            71         85   17   62645555.0
# 57       Pau Cubarsí            66         83   16   61813333.0
# 214         L. Miley            72         85   17   40223184.0
# 76    C. Hudson-Odoi            77         81   22   38208667.0
# 24        J. Zirkzee            81         86   22   37146111.0
# 117      Pau Cubarsí            66         83   16   35184499.0
# 410       A. Wharton            76         85   19   34753085.0
# 608         Jorginho            83         83   31   27873650.0
# 38         G. Rutter            78         86   21   27420987.0
# 248        L. Mercan            68         74   22   27353601.0
# 170     N. Broadhead            72         73   25   26193771.0
# 290           Fermín            74         81   20   22936736.0
# 1271         T. Weah            75         79   23   22131181.0
# 534         T. Rothe            69         83   18   21727534.0
# 252     J. Philogene            75         82   21   20295362.0
# 546          D. Alli            76         74   27   18862865.0
# 282       João Pedro            77         83   21   17982938.0
# 526           Morato            78         84   22   17458255.0
# 594      I. Sulemana            71         81   20   16889725.0
# 815         M. Vitík            77         82   20   15877391.0
# 1076      Tomé Sousa            60         84   16   15804162.0
# 871        C. Bassey            77         83   23   15758502.0
# 1224       I. Ndiaye            76         80   23   15275853.0
